# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('ParisHousing.csv')

# %%
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# 1      3653   2436     128               1             2  8085989.5
# 2      2937   8852     135               1             9  5574642.1
# 3       659   7141     359               0             3  3232561.2
# 4      8435   2429     292               1             4  7055052.0

# %%
d=df.drop(['hasYard','hasPool','isNewBuilt','hasStormProtector','hasStorageRoom'], axis=1)
X=d.drop(['price'],axis=1)
y=d.price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.25,random_state=55)
print(X_train.shape,Y_train.shape)
X_train.describe()
# Out:
# (7500, 11) (7500,)
#        squareMeters  numberOfRooms       floors      cityCode  cityPartRange  \
# count   7500.000000    7500.000000  7500.000000   7500.000000    7500.000000
# mean   49841.575467      50.139333    50.181467  49960.322267       5.488400
# std    28840.233948      28.852253    28.940047  29045.606690       2.883246
# min       89.000000       1.000000     1.000000      3.000000       1.000000
# 25%    25075.000000      25.000000    25.000000  24493.500000       3.000000
# 50%    50116.000000      50.000000    50.000000  50372.000000       5.000000
# 75%    74896.500000      75.000000    76.000000  75424.000000       8.000000
# max    99985.000000     100.000000   100.000000  99953.000000      10.000000
#
#        numPrevOwners         made      basement         attic       garage  \
# count    7500.000000  7500.000000   7500.000000   7500.000000  7500.000000
# mean        5.509067  2005.434267   5045.179333   5049.777733   553.128133
# std         2.845499     9.323858   2865.115121   2907.138692   261.099078
# min         1.000000  1990.000000      0.000000      1.000000   100.000000
# 25%         3.000000  1997.000000   2568.750000   2511.000000   329.000000
# 50%         5.000000  2005.000000   5106.500000   5095.000000   554.000000
# 75%         8.000000  2013.000000   7513.500000   7586.000000   777.000000
# max        10.000000  2021.000000  10000.000000  10000.000000  1000.000000
#
#        hasGuestRoom
# count   7500.000000
# mean       5.010267
# std        3.171504
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 9.99999174e+01,  5.02679263e-01,  5.38262795e+01,  1.04824073e-04,
#         6.16675886e+01, -1.94852455e+01,  1.32333071e-01,  3.19976990e-04,
#        -1.39967190e-02,  9.62631051e-02, -9.00008518e+00])

# %%
model.intercept_
# Out:
# 3268.3150242511183

# %%
y_pred_train=model.predict(X_train)
y_pred_test=model.predict(X_test)

# %%
Model_Test=pd.DataFrame(X_test)
Model_Test['Test Actual Outcome']=Y_test
Model_Test['Test Predicted Outcome']=y_pred_test
Model_Test['Test Predicted Outcome']=Model_Test['Test Predicted Outcome'].astype('int64')
Model_Test['Test Actual Outcome']=Model_Test['Test Actual Outcome'].astype('int64')
Model_Test
# Out:
#       squareMeters  numberOfRooms  floors  cityCode  cityPartRange  \
# 2082         68365             96      79     31033              5
# 679          49063             35      81     53623              1
# 2751         97452             83      54     29279             10
# 3295         27451             80      20     32205              4
# 5392         21857             93      16     35864              6
# ...            ...            ...     ...       ...            ...
# 6129         82311             85      98     52171              8
# 8735         30042             84      65     38907              6
# 2828         46910             80      99     32102              7
# 7718         97365             90      74     59928              4
# 8112         57243             22      10     35102              7
#
#       numPrevOwners  made  basement  attic  garage  hasGuestRoom  \
# 2082              7  1990      8246   4070     636             6
# 679               5  1991      9416   7968     972             7
# 2751              1  1992      9092    321     419             7
# 3295              3  2015       934   3608     354             9
# 5392              4  2006      8040   8580     147             5
# ...             ...   ...       ...    ...     ...           ...
# 6129              4  2012      9962   6386     164             0
# 8735              7  1999      1586   4054     142             2
# 2828              6  1994      4093   3721     890             8
# 7718             10  2007      9302   4806     491             0
# 8112             10  2014      2782   9257     348             2
#
#       Test Actual Outcome  Test Predicted Outcome
# 2082              6846772                 6844454
# 679               4909260                 4914097
# 2751              9751753                 9752248
# 3295              2747145                 2749843
# 5392              2191307                 2190287
# ...                   ...                     ...
# 6129              8239353                 8240295
# 8735              3008534                 3011448
# 2828              4706368                 4700178
# 7718              9738114                 9744095
# 8112              5729138                 5728506
#
# [2500 rows x 13 columns]

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred_test)
# Out:
# 0.9999989682923618

# %%
r2_score(Y_train,y_pred_train)
# Out:
# 0.9999990294454767

# %%
import pickle

# %%
with open ('HousePrdictionParis.pkl','wb') as file:
    pickle.dump(model,file)
